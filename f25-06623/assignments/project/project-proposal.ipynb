# %% [markdown]
# # Project proposal

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# Your project will be an original application of the topics we studied in this
# class. You have many options for what to do in your project. The project should be something that you are interested in, and that you think will be useful to you in the future. It should be something that requires each person to do about 8-10 hours of work. You will work in a team of ~3 people. This proposal is a team assignment.
#
# Here are some examples:
#
# 1. Develop a new lecture on a topic we did not discuss or that goes deeper into a topic we did not discuss.
#
# 2. You could develop a new function that implements some algorithm that is useful in scientific computing, and show examples of how it works.
#
# 3. You could use what we have done in class to reproduce an analysis in the literature
#
# 4. Or something else like these ideas.
#
# Eventually you will turn in a PDF that is a full narrative document with the
# code used to implement your project. I am anticipating it will take each person 8-10
# hours to complete this, and your project scope should match that
# expectation.
#
# The purpose of this assignment is for you to propose an idea for your project to
# get initial feedback on the idea.
#
# Prepare about a 1-page description of what your project will be about. There
# should be enough detail for me to evaluate its suitability. You could include
# some pseduocode examples if you want, to illustrate what you are thinking about.
#
# You should include how you plan to work together as a team. That could include how you plan to divide up the work, how you plan to communicate, and how you plan to resolve conflicts. You should also include a timeline for when you plan to complete the project.
#
#
# You will get feedback on your project proposal in Canvas.

# %% [markdown]
# # Summary of project
#
# Write a paragraph summary of your project idea.

# %% [markdown]
# # Tasks to be completed and timeline
#
# Describe the things you will need to do to complete your project. For each task, estimate how long you think it will take, and when they will be completed by. Estimate the total amount of time you will need to do the project.
#
# Include an example of a proof of concept example that would show it is feasible (you do not need to demonstrate that yet, but it is the next assignment to do that).

# %% [markdown]
# # Team work
#
# Describe the team work and the collaboration between the team members. How did you divide the work? How did you communicate? How did you make decisions? How did you resolve conflicts? How will you ensure that all team members contributed equally to the project?

# %% [markdown]
# When you are done, download a PDF and turn it in on Canvas. Make sure to save your notebook, then run this cell and click on the download link.

# %%
# %run ~/f25-06623/f25.py
# %pdf
