# %% [markdown]
# # linear algebra and mass balances
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# Xylene, styrene, toluene and benzene are separated in the following array of distillation columns. The total molar flow in to the first column is 70 kg-mol/min. The fractions provided are in mole%.
#
# Your goal is to determine the molar flow rates labeled $D_1, B_1, D_2$ and $B_2$. You can do this by developing a mole balance on each species, which should lead to 4 linear equations. Use `np.linalg.solve` to find these molar flow rates.
#
# ![](mass-balance.png)

# %% [markdown]
# Show using linear algebra that your solution is valid.

# %% [markdown]
# When you are done, download a PDF and turn it in on Canvas. Make sure to save your notebook, then run this cell and click on the download link.

# %%
# %run ~/f25-06623/f25.py
# %pdf
